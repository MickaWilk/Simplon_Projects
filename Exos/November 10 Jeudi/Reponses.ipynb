# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("lancers.csv", index_col=0)
df.dtypes
# Out:
# Groupe 1     object
# Groupe 2     object
# Groupe 3     object
# Groupe 4    float64
# Groupe 5      int64
# Groupe 6     object
# Groupe 7     object
# dtype: object

# %%
df = ((df.applymap(str)).applymap(lambda x: x.replace(",",".") if (type(x) == type("")) else x)).applymap(float)
df
# Out:
#              Groupe 1  Groupe 2  Groupe 3  Groupe 4  Groupe 5  Groupe 6  \
#
# Lancer n°1      -51.0      30.0      20.0       0.0      23.0      29.0
# Lancer n°2     -107.0     -43.0     -16.0       2.0     101.0      67.0
# Lancer n°3      -59.0    -123.5      37.0     -23.0      81.0      44.0
# Lancer n°4      -94.5     -59.5     -29.0      -2.0      16.0      26.0
# Lancer n°5      -64.0     -40.5       3.0       2.0     -41.0      88.0
# Lancer n°6       30.0       5.0      43.0      78.0     -59.0     -51.0
# Lancer n°7      -24.0      55.0     -21.0      70.0      -3.0     -63.0
# Lancer n°8       -1.0      -8.5     -13.0      -7.0      12.0      20.5
# Lancer n°9        3.0      87.0     -18.0      12.0    -140.0     -40.0
# Lancer n°10      37.0      44.5      24.0      81.0     -85.0     -33.5
# Lancer n°11     179.0     -62.5      13.5      20.0      10.0      30.0
# Lancer n°12      86.5     -30.0      28.0      61.0      46.0      29.0
# Lancer n°13     -39.5     -18.5      12.5      60.0     -12.0     -11.0
# Lancer n°14      -7.5      -4.2      43.0      66.0     -25.0     -25.0
# Lancer n°15      42.0      56.5      52.0      76.0     -17.0      -6.0
# Lancer n°16      33.0      52.7      54.0       8.0      -9.0     -10.0
# Lancer n°17      25.5      26.2      97.0      35.0      80.0      74.0
# Lancer n°18     -25.5      31.0     -55.0      35.0    -120.0     -45.0
# Lancer n°19      35.0      14.7      10.0      87.0      -5.0     -76.0
# Lancer n°20     -12.5      40.5      36.0     -22.0      28.0      12.0
# Lancer n°21     142.5      -7.3      -1.5     -21.5     -43.0      34.0
# Lancer n°22     -27.5      -4.5      -1.0      38.0     -14.0      30.0
# Lancer n°23      -2.5     -19.0      -7.0      22.0    -160.0       6.5
# Lancer n°24      35.5     -23.0     -21.5     -20.0     134.0     -42.0
# Lancer n°25     -66.0      41.0     -33.0     -24.0     -34.0      69.0
# Lancer n°26     -19.0     -39.0     -28.5     114.0      90.0      89.0
# Lancer n°27      -9.5     -48.0     -87.5     136.0     162.0     -50.0
# Lancer n°28       7.5     -12.4     -65.0       4.0     -90.0     -17.0
# Lancer n°29     174.0      10.0       0.5     -31.0     -52.0     -23.0
# Lancer n°30      63.0     -36.9     -29.0      50.0      10.0     -51.5
#
#              Groupe 7
#
# Lancer n°1       36.0
# Lancer n°2      -55.0
# Lancer n°3      -89.0
# Lancer n°4       -2.0
# Lancer n°5      -81.0
# Lancer n°6      -64.0
# Lancer n°7        0.0
# Lancer n°8       15.5
# Lancer n°9      140.0
# Lancer n°10     -30.0
# Lancer n°11      -3.5
# Lancer n°12     -20.0
# Lancer n°13     -35.0
# Lancer n°14     -84.0
# Lancer n°15     -89.0
# Lancer n°16     -50.0
# Lancer n°17     -63.5
# Lancer n°18      -8.0
# Lancer n°19     -20.0
# Lancer n°20      17.0
# Lancer n°21     -30.5
# Lancer n°22      15.5
# Lancer n°23      42.5
# Lancer n°24       8.5
# Lancer n°25       9.5
# Lancer n°26      27.0
# Lancer n°27      -1.0
# Lancer n°28     -22.0
# Lancer n°29     135.5
# Lancer n°30      -5.5

# %%
x = df.to_numpy().reshape(-1)
plt.hist(x)
# Out:
# (array([ 2.,  4., 18., 34., 62., 51., 18., 12.,  6.,  3.]),
#  array([-160. , -126.1,  -92.2,  -58.3,  -24.4,    9.5,   43.4,   77.3,
#          111.2,  145.1,  179. ]),
#  <BarContainer object of 10 artists>)

# %%
fig,ax = plt.subplots()
ax.plot(x)
