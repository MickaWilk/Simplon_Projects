# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("akinator IA3 - Feuille 1.csv")
df = df.loc[:, ~df.columns.str.match("Unnamed")]
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.drop(columns=["Mot préféré", "épaisseur du lobe d'oreille gauche (mm)", 'Plat préféré',
       'Signe astrologique', 'Gaming ?', 'Echecs', 'Allergies ?', 'Mac ou PC',
       'Des enfants?', 'Transport ?', 'Tatouage? ', 'Entreprise?',
       'Sucré ou salé?', 'Preference manuelle', ' Jour ou Nuit ',
       'Artiste musical préféré', 'Traduction artiste',
       'Mon "Martine" préféré', 'série préférée', 'Sport pratiqué', 'Film préféré', 'Année de naissance',
       'note du BAC en maths', 'Moyenne générale en CE2', "github name", "sur une île déserte, j'emmène..", "Animal totem", "email"], inplace=True)

# %%
df.plot(x='Taille de pied', y='Taille (cm)', ylabel='Taille (cm)', kind="scatter")
# Out:
# <AxesSubplot:xlabel='Taille de pied', ylabel='Taille (cm)'>

# %%
plt.figure()
x = df["Taille de pied"]
y = df["Taille (cm)"]
plt.scatter(x,y)
plt.step(min(x), max(y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1386/3413093712.py in <module>
#       2 x = df["Taille de pied"]
#       3 y = df["Taille (cm)"]
# ----> 4 plt.subplot(000)
#       5 plt.scatter(x,y)
#       6 plt.subplot(222)
#
# ~/.pyenv/versions/simplon/lib/python3.8/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1266
#    1267     # First, search for an existing subplot with a matching spec.
# -> 1268     key = SubplotSpec._from_subplot_args(fig, args)
#    1269
#    1270     for ax in fig.axes:
#
# ~/.pyenv/versions/simplon/lib/python3.8/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     586                 rows, cols, num = map(int, str(arg))
#     587             except ValueError:
# --> 588                 raise ValueError(
#     589                     f"Single argument to subplot must be a three-digit "
#     590                     f"integer, not {arg!r}") from None
#
# ValueError: Single argument to subplot must be a three-digit integer, not 0
